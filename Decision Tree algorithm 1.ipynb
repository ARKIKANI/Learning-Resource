# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# %%
iris= load_iris()


x=iris.data
y=iris.target

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()   #max_deapth=3 for deapthness of data

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %%
#plotting the trees

from sklearn.tree import plot_tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']= 80,50           #to increase the size

plot_tree(clf)
# Out:
# [Text(1984.0, 2491.5, 'X[3] <= 0.8\ngini = 0.664\nsamples = 120\nvalue = [38, 37, 45]'),
#  Text(1488.0, 2038.5, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(2480.0, 2038.5, 'X[3] <= 1.75\ngini = 0.495\nsamples = 82\nvalue = [0, 37, 45]'),
#  Text(1984.0, 1585.5, 'X[2] <= 4.95\ngini = 0.21\nsamples = 42\nvalue = [0, 37, 5]'),
#  Text(992.0, 1132.5, 'X[0] <= 4.95\ngini = 0.054\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(496.0, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1488.0, 679.5, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(2976.0, 1132.5, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(2480.0, 679.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(3472.0, 679.5, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(2976.0, 226.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(3968.0, 226.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(2976.0, 1585.5, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 40]')]
